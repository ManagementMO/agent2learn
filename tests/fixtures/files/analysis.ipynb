# %% [markdown]
# # Analysis
#
# Inline image: ![tiny](attachment:tiny.png)

# %%
print('hello')
# a fence in the body: ```
# Out:
# hello
#    col_a  col_b
# 0      1      2

# %%
raise ValueError('example')
# Out:
# ValueError: example

# %%
display_unsupported()
